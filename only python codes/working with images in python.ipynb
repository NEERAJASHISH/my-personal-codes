# %%
from PIL import Image

# %%
mac = Image.open("this webscrap.jpg")
mac
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=285x190 at 0x1A96C57E040>

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac.size
# Out:
# (285, 190)

# %%
mac.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
croped_mac = mac.crop((0,0,100,100))
croped_mac
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x1A96D9B28E0>

# %% [markdown]
# # sample programme for the practise

# %%
dic = {}

r = input("enter the first name:\n")

for i in r:
    if  i in dic:
        dic[i] = dic[i] + 1
    else:
        dic[i] = 1
        
print(dic)
# Out:
# enter the first name:
# neeraj
# {'n': 1, 'e': 2, 'r': 1, 'a': 1, 'j': 1}

# %% [markdown]
# # cropping the images

# %%
# bottom of the page

# %%
mac.size
# Out:
# (285, 190)

# %%
x = 0
y = 0
width = 200
height  = 100




croper = mac.crop((0,0,width,height))
croper
# Out:
# <PIL.Image.Image image mode=RGB size=200x100 at 0x1A96D9E1070>

# %%
x = 0
y = 0
width  = 285/30
height = 190/10
cro  = mac.crop((0,0,width,height))
cro
# Out:
# <PIL.Image.Image image mode=RGB size=10x19 at 0x1A96DDA7370>

# %%
x = 0
y = 0
width  = 285/8 # add some of the constant values
height = 192   # add some of the changable values
cro  = mac.crop((0,0,width,height))
# Out:
# <PIL.Image.Image image mode=RGB size=36x192 at 0x1A96DC14F10>
